# %%
cust_sales_above_2000=customer_sales[customer_sales['sales']>2000]
cust_sales_above_2000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cust_sales_above_2000=customer_sales[customer_sales['sales']>2000]
#       2 cust_sales_above_2000
#
# NameError: name 'customer_sales' is not defined

# %%
sales_cust=pd1.merge(sales,cust,on='customer_id')
sales_cust
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 0     CA-2016-152156  2024-08-17  2024-08-24  Standard Class    CG-12520
# 1     CA-2016-152156  2024-08-17  2024-08-24  Standard Class    CG-12520
# 2     CA-2016-152156  2024-08-17  2024-08-24  Standard Class    CG-12520
# 3     CA-2016-152156  2024-08-17  2024-08-24  Standard Class    CG-12520
# 4     CA-2016-152156  2024-08-17  2024-08-24  Standard Class    CG-12520
# ...              ...         ...         ...             ...         ...
# 9987  CA-2015-103772  2015-06-28  2015-07-02  Standard Class    MP-17470
# 9988  US-2015-151435  2015-09-06  2015-09-09    Second Class    SW-20455
# 9989  CA-2015-100251  2015-05-17  2015-05-23  Standard Class    DV-13465
# 9990  CA-2015-100251  2015-05-17  2015-05-23  Standard Class    DV-13465
# 9991  CA-2014-110422  2014-01-21  2014-01-23    Second Class    TB-21400
#
#            product_id     sales  quantity  discount   profit  \
# ...

# %%
import pandas as pd1

cust=pd1.read_csv("C:/Users/HP/Downloads/customer.csv",header=0,index_col=0)
cust
# Out:
#                  customer_name      segment   age        country         city  \
# customer_id
# GH-14485             Gene Hale    Corporate  28.0  United States   Richardson
# SN-20710          Steve Nguyen  Home Office  46.0  United States      Houston
# LC-16930        Linda Cazamias    Corporate  31.0  United States   Naperville
# ES-14080            Erin Smith    Corporate  20.0  United States    Melbourne
# ON-18715         Odella Nelson    Corporate  27.0  United States        Eagan
# ...                        ...          ...   ...            ...          ...
# RE-19405       Ricardo Emerson     Consumer  35.0  United States         Kent
# SM-20905     Susan MacKendrick     Consumer  46.0  United States       Newark
# id-12345                   arc       arc-da  24.0          india       nagpur
# id-12346                  arc1      arc-da1  27.0          india       nagpur
# RA-19885          Ruben Ausman   Corporate1  51.0  United States  Los Angeles
#
# ...

# %%
 import pandas as pd1

 sales=pd1.read_csv("C:/Users/HP/Downloads/sales.csv",header=0,index_col=0)
 sales
# Out:
#                   order_id  order_date   ship_date       ship_mode  \
# order_line
# 9997        CA-2016-152156  2024-08-17  2024-08-24  Standard Class
# 9997        CA-2016-152156  2024-08-17  2024-08-24  Standard Class
# 11122       CA-2016-152156  2024-08-17  2024-08-24  Standard Class
# 11122       CA-2016-152156  2024-08-17  2024-08-24  Standard Class
# 11122       CA-2016-152156  2024-08-17  2024-08-24  Standard Class
# ...                    ...         ...         ...             ...
# 9972        CA-2015-103772  2015-06-28  2015-07-02  Standard Class
# 9981        US-2015-151435  2015-09-06  2015-09-09    Second Class
# 9985        CA-2015-100251  2015-05-17  2015-05-23  Standard Class
# 9986        CA-2015-100251  2015-05-17  2015-05-23  Standard Class
# 9990        CA-2014-110422  2014-01-21  2014-01-23    Second Class
#
#            customer_id       product_id     sales  quantity  discount   profit
# order_line
# ...
